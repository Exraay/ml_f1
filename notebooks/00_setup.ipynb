# %% [markdown]
# # 00 - Setup
# Build or load the base dataset. This notebook is safe to rerun.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import numpy as np
import pandas as pd

# %%
from _common import build_dataset_if_missing

df, metadata = build_dataset_if_missing()
df.head()
# Out:
#    LapNumber  Stint  TyreLife  LapTimeLag1  LapTimeLag2  LapTimeLag3  \
# 0        2.0    1.0       2.0          NaN          NaN          NaN
# 1        3.0    1.0       3.0      100.548          NaN          NaN
# 2        4.0    1.0       4.0      100.664      100.548          NaN
# 3        5.0    1.0       5.0      101.126      100.664      100.548
# 4        6.0    1.0       6.0      102.303      101.126      100.664
#
#    RollingMean3  EstimatedFuelWeight  FuelEffect  TireDegradation  ...  \
# 0           NaN                 96.0        0.96            0.070  ...
# 1    100.548000                 94.0        0.94            0.105  ...
# 2    100.606000                 92.0        0.92            0.140  ...
# 3    100.779333                 90.0        0.90            0.175  ...
# 4    101.364333                 88.0        0.88            0.210  ...
#
#        Team  Compound  TrackStatusFlag  Circuit  TireAgeCategory  \
# ...
